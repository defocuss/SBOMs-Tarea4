# %% [markdown]
# # Análisis de Vulnerabilidades con Grype
#
# Este notebook ejecuta un análisis de vulnerabilidades en dependencias sobre los repositorios clonados en `data/repos/` utilizando Grype, la herramienta de escaneo de componentes de software de Anchore.
#
# ## ¿Qué es Grype?
#
# Grype es un escáner de vulnerabilidades que:
# - Busca vulnerabilidades conocidas en dependencias y librerías
# - Detecta manifests de dependencias (package.json, requirements.txt, pom.xml, etc)
# - Compara contra bases de datos de vulnerabilidades (CVE, GitHub Advisories)
# - Retorna severidad y versiones de corrección
#
# ## Flujo de Ejecución
#
# 1. **Descubrimiento de repositorios**: Escanea `data/repos/` para encontrar todos los subdirectorios
# 2. **Detección de manifests**: Busca archivos de dependencias (package.json, requirements.txt, etc)
# 3. **Análisis con Grype**: Para cada repositorio, ejecuta Grype para encontrar vulnerabilidades
# 4. **Generación de resultados**: Los hallazgos se guardan en dos formatos:
#    - Raw: `{repo}-grype-raw.json` (salida original de Grype para debug)
#    - Normalizado: `{repo}-grype.json` (formato procesado para análisis)

# %% [markdown]
# ## Preparación: Importar `scripts/generate_grype.py`
#
# A continuación importaremos el módulo `GrypeAnalyzer` desde el archivo `scripts/generate_grype.py`.

# %%
import sys
from pathlib import Path
import json
import pandas as pd

# Agregar el directorio scripts al path para importar el modulo generate_grype
# Este módulo contiene la clase GrypeAnalyzer que orquesta todo el análisis
project_root = Path().cwd().parent.parent
scripts_path = project_root / "scripts"
if str(scripts_path) not in sys.path:
    sys.path.insert(0, str(scripts_path))

print(f"Notebook working directory: {Path().cwd()}")
print(f"Project root: {project_root}")
print(f"Scripts path: {scripts_path}")
print(f"Importing from: generate_grype.py")
# Out:
# Notebook working directory: /workspaces/SBOMS-FASTAPI-2/nbs/vuln
# Project root: /workspaces/SBOMS-FASTAPI-2
# Scripts path: /workspaces/SBOMS-FASTAPI-2/scripts
# Importing from: generate_grype.py

# %%
# Importar la clase GrypeAnalyzer desde generate_grype.py
from generate_grype import GrypeAnalyzer

print("✓ Importado correctamente: GrypeAnalyzer desde scripts/generate_grype.py")
# Out:
# ✓ Importado correctamente: GrypeAnalyzer desde scripts/generate_grype.py

# %% [markdown]
# ## Configuración

# %%
# Configurar rutas
repos_path = project_root / "data" / "repos"
output_path = project_root / "data" / "results"

# Crear analizador
analizador = GrypeAnalyzer(
    repos_path=str(repos_path),
    output_path=str(output_path)
)

# Configurar para ejecución normal (no dry-run)
analizador.dry_run = False

print(f"Repos path: {repos_path}")
print(f"Output path: {output_path}")
print(f"Dry run: {analizador.dry_run}")
# Out:
# Repos path: /workspaces/SBOMS-FASTAPI-2/data/repos
# Output path: /workspaces/SBOMS-FASTAPI-2/data/results
# Dry run: False

# %% [markdown]
# ## Ejecución: Análisis de Vulnerabilidades (usando `scripts/generate_grype.py`)
#
# Ahora ejecutaremos el análisis de vulnerabilidades sobre todos los repositorios descubiertos. El script `generate_grype.py` manejará automáticamente la orquestación completa.

# %%
# Descubrir repositorios usando el método del GrypeAnalyzer
# Este método viene de scripts/generate_grype.py
repositorios = analizador.discover_repositories()
print(f"Repositorios encontrados: {len(repositorios)}")
for repo in repositorios:
    print(f"  - {repo}")
# Out:
# Repositorios encontrados: 9
#   - data/repos/annotated-doc
#   - data/repos/asyncer
#   - data/repos/fastapi
#   - data/repos/fastapi-cli
#   - data/repos/fastapi-new
#   - data/repos/fastapi-vscode
#   - data/repos/full-stack-fastapi-template
#   - data/repos/sqlmodel
#   - data/repos/typer

# %%
# | eval: false
print("Iniciando análisis de vulnerabilidades con scripts/generate_grype.py...")
analizador.run()
print("✓ Análisis completado")
# Out:
# INFO | === Grype Environment Diagnostics ===
# Iniciando análisis de vulnerabilidades con scripts/generate_grype.py...
# INFO | Grype CLI: Application:         grype
# Version:             0.111.0
# BuildDate:           2026-04-09T13:14:56Z
# GitCommit:           1f19355a7ee2d7e2bd58da6255bdeb618eb0c0d1
# GitDescription:      v0.111.0
# Platform:            linux/amd64
# GoVersion:           go1.25.9
# Compiler:            gc
# Syft Version:        v1.42.4
# Supported DB Schema: 6
# INFO | Grype DB status: Path:      /home/vscode/.cache/grype/db/6/vulnerability.db
# Schema:    v6.1.4
# Built:     2026-04-20T07:05:07Z
# From:      https://grype.anchore.io/databases/v6/vulnerability-db_v6.1.4_2026-04-20T00:38:53Z_1776668707.tar.zst?checksum=sha256%3Aff674a323b31f970997f7a62dcd22d50248296d81860d0767aae5ad8759f378c
# Status:    valid
# INFO | === Environment Check Complete ===
#
# INFO | [1/9] Scanning data/repos/annotated-doc with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# INFO | Manifests found in annotated-doc: requirements.txt
# INFO | Running Grype on annotated-doc...
# INFO | Parsing Grype output...
# INFO | Found 4 matches in Grype output
# INFO | Parsed 4 vulnerabilities total
# INFO | Raw Grype output saved to data/results/annotated-doc-grype-raw.json
# INFO | Normalized analysis saved to data/results/annotated-doc-grype.json
# INFO | [2/9] Scanning data/repos/asyncer with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# anyio==4.13.0
#     # via asyncer (pyproject.toml)
# idna==3.11
#     # via anyio
# sniffio==1.3.1
#     # via asyncer (pyproject.toml)
# typing-extensions==4.15.0 ; python_version < "3.15"
#     # via
#     #   anyio
#     #   asyncer (pyproject.toml)
# INFO | Manifests found in asyncer: requirements.txt
# INFO | Running Grype on asyncer...
# INFO | Parsing Grype output...
# INFO | Found 5 matches in Grype output
# INFO | Parsed 5 vulnerabilities total
# INFO | Raw Grype output saved to data/results/asyncer-grype-raw.json
# INFO | Normalized analysis saved to data/results/asyncer-grype.json
# INFO | [3/9] Scanning data/repos/fastapi with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi (pyproject.toml)
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# idna==3.11
#     # via anyio
# pydantic==2.13.3
#     # via fastapi (pyproject.toml)
# pydantic-core==2.46.3
#     # via pydantic
# starlette==1.0.0
#     # via fastapi (pyproject.toml)
# typing-extensions==4.15.0
#     # via
#     #   anyio
#     #   fastapi (pyproject.toml)
#     #   pydantic
#     #   pydantic-core
#     #   starlette
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi (pyproject.toml)
#     #   pydantic
# INFO | Manifests found in fastapi: requirements.txt
# INFO | Running Grype on fastapi...
# INFO | Parsing Grype output...
# INFO | Found 13 matches in Grype output
# INFO | Parsed 13 vulnerabilities total
# INFO | Raw Grype output saved to data/results/fastapi-grype-raw.json
# INFO | Normalized analysis saved to data/results/fastapi-grype.json
# INFO | [4/9] Scanning data/repos/fastapi-cli with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via typer
# anyio==4.13.0
#     # via watchfiles
# click==8.3.2
#     # via
#     #   rich-toolkit
#     #   typer
#     #   uvicorn
# h11==0.16.0
#     # via uvicorn
# httptools==0.7.1
#     # via uvicorn
# idna==3.11
#     # via anyio
# markdown-it-py==4.0.0
#     # via rich
# mdurl==0.1.2
#     # via markdown-it-py
# pygments==2.20.0
#     # via rich
# python-dotenv==1.2.2
#     # via uvicorn
# pyyaml==6.0.3
#     # via uvicorn
# rich==15.0.0
#     # via
#     #   rich-toolkit
#     #   typer
# rich-toolkit==0.19.7
#     # via fastapi-cli (pyproject.toml)
# shellingham==1.5.4
#     # via typer
# typer==0.24.1
#     # via fastapi-cli (pyproject.toml)
# typing-extensions==4.15.0
#     # via
#     #   anyio
#     #   rich-toolkit
# uvicorn==0.44.0
#     # via fastapi-cli (pyproject.toml)
# uvloop==0.22.1
#     # via uvicorn
# watchfiles==1.1.1
#     # via uvicorn
# websockets==16.0
#     # via uvicorn
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# Backend subprocess exited when trying to invoke get_requires_for_build_wheel
# Failed to parse /workspaces/SBOMS-FASTAPI-2/data/repos/fastapi-cli/tests/assets/pyproject_config/pyproject.toml
# INFO | Manifests found in fastapi-cli: requirements.txt
# INFO | Running Grype on fastapi-cli...
# INFO | Parsing Grype output...
# INFO | Found 1 matches in Grype output
# INFO | Parsed 1 vulnerabilities total
# INFO | Raw Grype output saved to data/results/fastapi-cli-grype-raw.json
# INFO | Normalized analysis saved to data/results/fastapi-cli-grype.json
# INFO | [5/9] Scanning data/repos/fastapi-new with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via typer
# click==8.3.2
#     # via
#     #   rich-toolkit
#     #   typer
# markdown-it-py==4.0.0
#     # via rich
# mdurl==0.1.2
#     # via markdown-it-py
# pygments==2.20.0
#     # via rich
# rich==15.0.0
#     # via
#     #   fastapi-new (pyproject.toml)
#     #   rich-toolkit
#     #   typer
# rich-toolkit==0.19.7
#     # via fastapi-new (pyproject.toml)
# shellingham==1.5.4
#     # via typer
# typer==0.24.1
#     # via fastapi-new (pyproject.toml)
# typing-extensions==4.15.0
#     # via
#     #   fastapi-new (pyproject.toml)
#     #   rich-toolkit
# INFO | Manifests found in fastapi-new: requirements.txt
# INFO | Running Grype on fastapi-new...
# INFO | Parsing Grype output...
# INFO | Found 2 matches in Grype output
# INFO | Parsed 2 vulnerabilities total
# INFO | Raw Grype output saved to data/results/fastapi-new-grype-raw.json
# INFO | Normalized analysis saved to data/results/fastapi-new-grype.json
# INFO | [6/9] Scanning data/repos/fastapi-vscode with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# INFO | Manifests found in fastapi-vscode: package.json, requirements.txt
# INFO | Running Grype on fastapi-vscode...
# INFO | Parsing Grype output...
# INFO | Found 0 matches in Grype output
# INFO | Parsed 0 vulnerabilities total
# INFO | Raw Grype output saved to data/results/fastapi-vscode-grype-raw.json
# INFO | Normalized analysis saved to data/results/fastapi-vscode-grype.json
# INFO | [7/9] Scanning data/repos/full-stack-fastapi-template with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# Backend subprocess exited when trying to invoke get_requires_for_build_wheel
# Failed to parse /workspaces/SBOMS-FASTAPI-2/data/repos/full-stack-fastapi-template/pyproject.toml
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# alembic==1.18.4
#     # via app (pyproject.toml)
# annotated-doc==0.0.4
#     # via
#     #   fastapi
#     #   typer
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   starlette
#     #   watchfiles
# argon2-cffi==25.1.0
#     # via pwdlib
# argon2-cffi-bindings==25.1.0
#     # via argon2-cffi
# bcrypt==5.0.0
#     # via pwdlib
# cachetools==7.0.6
#     # via premailer
# certifi==2026.2.25
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
#     #   sentry-sdk
# cffi==2.0.0
#     # via argon2-cffi-bindings
# chardet==7.4.3
#     # via
#     #   emails
#     #   encutils
# charset-normalizer==3.4.7
#     # via requests
# click==8.3.2
#     # via
#     #   rich-toolkit
#     #   typer
#     #   uvicorn
# cssselect==1.4.0
#     # via premailer
# cssutils==2.14.0
#     # via
#     #   emails
#     #   premailer
# dnspython==2.8.0
#     # via email-validator
# email-validator==2.3.0
#     # via
#     #   app (pyproject.toml)
#     #   fastapi
#     #   pydantic
# emails==0.6
#     # via app (pyproject.toml)
# encutils==1.0.0
#     # via cssutils
# fastapi==0.136.0
#     # via
#     #   app (pyproject.toml)
#     #   sentry-sdk
# fastapi-cli==0.0.24
#     # via fastapi
# fastapi-cloud-cli==0.17.0
#     # via fastapi-cli
# fastar==0.11.0
#     # via
#     #   fastapi
#     #   fastapi-cloud-cli
# greenlet==3.4.0
#     # via sqlalchemy
# h11==0.16.0
#     # via
#     #   httpcore
#     #   uvicorn
# httpcore==1.0.9
#     # via httpx
# httptools==0.7.1
#     # via uvicorn
# httpx==0.28.1
#     # via
#     #   app (pyproject.toml)
#     #   fastapi
#     #   fastapi-cloud-cli
# idna==3.11
#     # via
#     #   anyio
#     #   email-validator
#     #   httpx
#     #   requests
# jinja2==3.1.6
#     # via
#     #   app (pyproject.toml)
#     #   fastapi
# lxml==6.1.0
#     # via
#     #   emails
#     #   premailer
# mako==1.3.11
#     # via alembic
# markdown-it-py==4.0.0
#     # via rich
# markupsafe==3.0.3
#     # via
#     #   jinja2
#     #   mako
# mdurl==0.1.2
#     # via markdown-it-py
# more-itertools==11.0.2
#     # via cssutils
# premailer==3.10.0
#     # via emails
# psycopg==3.3.3
#     # via app (pyproject.toml)
# psycopg-binary==3.3.3
#     # via psycopg
# pwdlib==0.3.0
#     # via app (pyproject.toml)
# pycparser==3.0
#     # via cffi
# pydantic==2.13.3
#     # via
#     #   app (pyproject.toml)
#     #   fastapi
#     #   fastapi-cloud-cli
#     #   pydantic-extra-types
#     #   pydantic-settings
#     #   sqlmodel
# pydantic-core==2.46.3
#     # via pydantic
# pydantic-extra-types==2.11.1
#     # via fastapi
# pydantic-settings==2.14.0
#     # via
#     #   app (pyproject.toml)
#     #   fastapi
# pygments==2.20.0
#     # via rich
# pyjwt==2.12.1
#     # via app (pyproject.toml)
# python-dateutil==2.9.0.post0
#     # via emails
# python-dotenv==1.2.2
#     # via
#     #   pydantic-settings
#     #   uvicorn
# python-multipart==0.0.26
#     # via
#     #   app (pyproject.toml)
#     #   fastapi
# pyyaml==6.0.3
#     # via uvicorn
# requests==2.33.1
#     # via
#     #   emails
#     #   premailer
# rich==15.0.0
#     # via
#     #   rich-toolkit
#     #   typer
# rich-toolkit==0.19.7
#     # via
#     #   fastapi-cli
#     #   fastapi-cloud-cli
# rignore==0.7.6
#     # via fastapi-cloud-cli
# sentry-sdk==2.58.0
#     # via
#     #   app (pyproject.toml)
#     #   fastapi-cloud-cli
# shellingham==1.5.4
#     # via typer
# six==1.17.0
#     # via python-dateutil
# sqlalchemy==2.0.49
#     # via
#     #   alembic
#     #   sqlmodel
# sqlmodel==0.0.38
#     # via app (pyproject.toml)
# starlette==1.0.0
#     # via fastapi
# tenacity==8.5.0
#     # via app (pyproject.toml)
# typer==0.24.1
#     # via
#     #   fastapi-cli
#     #   fastapi-cloud-cli
# typing-extensions==4.15.0
#     # via
#     #   alembic
#     #   anyio
#     #   fastapi
#     #   psycopg
#     #   pydantic
#     #   pydantic-core
#     #   pydantic-extra-types
#     #   rich-toolkit
#     #   sqlalchemy
#     #   sqlmodel
#     #   starlette
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-settings
# urllib3==2.6.3
#     # via
#     #   requests
#     #   sentry-sdk
# uvicorn==0.44.0
#     # via
#     #   fastapi
#     #   fastapi-cli
#     #   fastapi-cloud-cli
# uvloop==0.22.1
#     # via uvicorn
# watchfiles==1.1.1
#     # via uvicorn
# websockets==16.0
#     # via uvicorn
# INFO | Manifests found in full-stack-fastapi-template: package.json, requirements.txt
# INFO | Running Grype on full-stack-fastapi-template...
# INFO | Parsing Grype output...
# INFO | Found 8 matches in Grype output
# INFO | Parsed 8 vulnerabilities total
# INFO | Raw Grype output saved to data/results/full-stack-fastapi-template-grype-raw.json
# INFO | Normalized analysis saved to data/results/full-stack-fastapi-template-grype.json
# INFO | [8/9] Scanning data/repos/sqlmodel with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-types==0.7.0
#     # via pydantic
# greenlet==3.4.0
#     # via sqlalchemy
# pydantic==2.13.3
#     # via sqlmodel (pyproject.toml)
# pydantic-core==2.46.3
#     # via pydantic
# sqlalchemy==2.0.49
#     # via sqlmodel (pyproject.toml)
# typing-extensions==4.15.0
#     # via
#     #   pydantic
#     #   pydantic-core
#     #   sqlalchemy
#     #   sqlmodel (pyproject.toml)
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# INFO | Manifests found in sqlmodel: requirements.txt
# INFO | Running Grype on sqlmodel...
# INFO | Parsing Grype output...
# INFO | Found 8 matches in Grype output
# INFO | Parsed 8 vulnerabilities total
# INFO | Raw Grype output saved to data/results/sqlmodel-grype-raw.json
# INFO | Normalized analysis saved to data/results/sqlmodel-grype.json
# INFO | [9/9] Scanning data/repos/typer with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.11
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via typer (pyproject.toml)
# click==8.3.2
#     # via typer (pyproject.toml)
# markdown-it-py==4.0.0
#     # via rich
# mdurl==0.1.2
#     # via markdown-it-py
# pygments==2.20.0
#     # via rich
# rich==15.0.0
#     # via typer (pyproject.toml)
# shellingham==1.5.4
#     # via typer (pyproject.toml)
# INFO | Manifests found in typer: requirements.txt
# INFO | Running Grype on typer...
# INFO | Parsing Grype output...
# INFO | Found 1 matches in Grype output
# INFO | Parsed 1 vulnerabilities total
# INFO | Raw Grype output saved to data/results/typer-grype-raw.json
# INFO | Normalized analysis saved to data/results/typer-grype.json
# INFO | Summary | total_repos=9 | repos_scanned=9 | files_generated=18 | skipped=0 | errors=0
# ✓ Análisis completado

# %% [markdown]
# ## Inspección de Resultados

# %%
# | eval: false
# Listar archivos de resultados generados
output_path = project_root / "data" / "results"
grype_files = sorted(output_path.glob("*-grype.json"))
grype_raw_files = sorted(output_path.glob("*-grype-raw.json"))

print(f"📁 Buscando en: {output_path}")
print(f"✓ Archivos de análisis Grype (normalizados): {len(grype_files)}")
for archivo in grype_files:
    tamaño = archivo.stat().st_size / 1024  # KB
    print(f"  - {archivo.name} ({tamaño:.1f} KB)")

print(f"\n✓ Archivos de análisis Grype (raw): {len(grype_raw_files)}")
for archivo in grype_raw_files:
    tamaño = archivo.stat().st_size / 1024  # KB
    print(f"  - {archivo.name} ({tamaño:.1f} KB)")
# Out:
# 📁 Buscando en: /workspaces/SBOMS-FASTAPI-2/data/results
# ✓ Archivos de análisis Grype (normalizados): 9
#   - annotated-doc-grype.json (1.6 KB)
#   - asyncer-grype.json (2.0 KB)
#   - fastapi-cli-grype.json (0.7 KB)
#   - fastapi-grype.json (4.8 KB)
#   - fastapi-new-grype.json (1.0 KB)
#   - fastapi-vscode-grype.json (0.3 KB)
#   - full-stack-fastapi-template-grype.json (3.1 KB)
#   - sqlmodel-grype.json (3.1 KB)
#   - typer-grype.json (0.7 KB)
#
# ✓ Archivos de análisis Grype (raw): 9
#   - annotated-doc-grype-raw.json (19.1 KB)
#   - asyncer-grype-raw.json (22.9 KB)
#   - fastapi-cli-grype-raw.json (9.6 KB)
#   - fastapi-grype-raw.json (52.3 KB)
#   - fastapi-new-grype-raw.json (12.8 KB)
#   - fastapi-vscode-grype-raw.json (5.1 KB)
#   - full-stack-fastapi-template-grype-raw.json (31.0 KB)
#   - sqlmodel-grype-raw.json (35.5 KB)
#   - typer-grype-raw.json (9.6 KB)

# %%
# | eval: false
# Cargar y mostrar resumen de UN análisis
results_dir = project_root / "data" / "results"
results_files = sorted(results_dir.glob("*-grype.json"))

print(f"📂 Buscando en: {results_dir}")
print(f"📋 Archivos encontrados: {len(results_files)}")

if results_files:
    result_file = results_files[0]
    print(f"📖 Leyendo: {result_file.name}")

    with open(result_file, 'r', encoding='utf-8') as f:
        data_content = json.load(f)

    repo_name_clean = result_file.stem.replace('-grype', '')
    total_found = data_content.get('total_vulnerabilities', 0)

    print(f"\n📊 ANÁLISIS: {repo_name_clean}")
    print(f"{'='*50}")
    print(f"✓ Total de vulnerabilidades encontradas: {total_found}")

    if total_found > 0:
        severity_data = data_content.get('vulnerabilities_by_severity', {})
        print(f"\n🔍 Vulnerabilidades por severidad:")
        for severity_type, count in severity_data.items():
            if count > 0:
                emoji = "🔴" if severity_type == "critical" else "🟠" if severity_type == "high" else "🟡" if severity_type == "medium" else "⚪"
                print(f"  {emoji} {severity_type}: {count}")
    else:
        print("⚠️  No se encontraron vulnerabilidades")
else:
    print("❌ No se encontraron archivos de análisis Grype")
# Out:
# 📂 Buscando en: /workspaces/SBOMS-FASTAPI-2/data/results
# 📋 Archivos encontrados: 9
# 📖 Leyendo: annotated-doc-grype.json
#
# 📊 ANÁLISIS: annotated-doc
# ==================================================
# ✓ Total de vulnerabilidades encontradas: 4
#
# 🔍 Vulnerabilidades por severidad:
#   ⚪ low: 4

# %%
# | eval: false
# Mostrar vulnerabilidades detalladas
output_path_det = project_root / "data" / "results"
grype_files_det = sorted(output_path_det.glob("*-grype.json"))

if grype_files_det:
    archivo_det = grype_files_det[0]

    with open(archivo_det, 'r', encoding='utf-8') as f:
        analisis_det = json.load(f)

    vulnerabilities_list = analisis_det.get('vulnerabilities', [])

    print(f"📋 Leyendo: {archivo_det.name}")
    print(
        f"📊 Total de vulnerabilidades en archivo: {len(vulnerabilities_list)}")

    if vulnerabilities_list:
        # Crear DataFrame con las vulnerabilidades
        df_vulns = pd.DataFrame(vulnerabilities_list)

        # Seleccionar y reordenar columnas
        cols_mostrar = ['package_name', 'current_version',
                        'vuln_id', 'vuln_severity', 'fix_version']
        cols_disponibles = [c for c in cols_mostrar if c in df_vulns.columns]
        df_mostrar = df_vulns[cols_disponibles].head(20)

        print(f"\n📋 Primeras 20 vulnerabilidades encontradas:")
        print(f"{'='*120}")
        for idx, row in df_mostrar.iterrows():
            print(
                f"\n{idx+1}. [{row['vuln_severity'].upper()}] {row['vuln_id']}")
            print(
                f"   📦 {row['package_name']} (actual: {row['current_version']})")
            if pd.notna(row['fix_version']) and row['fix_version'] != 'N/A':
                print(f"   ✓ Fix disponible en: {row['fix_version']}")

        if len(vulnerabilities_list) > 20:
            print(
                f"\n... y {len(vulnerabilities_list)-20} vulnerabilidades más")
    else:
        print("⚠️  No hay detalles de vulnerabilidades en el archivo")
# Out:
# 📋 Leyendo: annotated-doc-grype.json
# 📊 Total de vulnerabilidades en archivo: 4
#
# 📋 Primeras 20 vulnerabilidades encontradas:
# ========================================================================================================================
#
# 1. [LOW] GHSA-5239-wwwm-4pmq
#    📦 pygments (actual: 2.19.2)
#
# 2. [LOW] GHSA-6w46-j5rx-g56g
#    📦 pytest (actual: 8.3.5)
#
# 3. [LOW] GHSA-6w46-j5rx-g56g
#    📦 pytest (actual: 8.4.2)
#
# 4. [LOW] GHSA-6w46-j5rx-g56g
#    📦 pytest (actual: 9.0.2)

# %% [markdown]
# ## Análisis Detallado de Vulnerabilidades

# %%
# | eval: false
# Compilar estadísticas consolidadas
from collections import defaultdict

output_path_stats = project_root / "data" / "results"
grype_files_stats = sorted(output_path_stats.glob("*-grype.json"))

stats_consolidadas = {
    'total_repositories': len(grype_files_stats),
    'total_vulnerabilities': 0,
    'vulnerabilities_by_repo': {},
    'vulnerabilities_by_severity': defaultdict(int),
    'top_packages': defaultdict(int)
}

for archivo in grype_files_stats:
    with open(archivo, 'r', encoding='utf-8') as f:
        data = json.load(f)

    repo_name = archivo.stem.replace('-grype', '')
    total = data.get('total_vulnerabilities', 0)

    stats_consolidadas['total_vulnerabilities'] += total
    stats_consolidadas['vulnerabilities_by_repo'][repo_name] = total

    # Contar por severidad
    for severity, count in data.get('vulnerabilities_by_severity', {}).items():
        stats_consolidadas['vulnerabilities_by_severity'][severity] += count

    # Contar top packages con vulnerabilidades
    for vuln in data.get('vulnerabilities', []):
        pkg = vuln.get('package', 'unknown')
        stats_consolidadas['top_packages'][pkg] += 1

# Convertir defaultdicts a dicts para visualización
stats_consolidadas['vulnerabilities_by_severity'] = dict(
    stats_consolidadas['vulnerabilities_by_severity'])
stats_consolidadas['top_packages'] = dict(sorted(
    stats_consolidadas['top_packages'].items(),
    key=lambda x: x[1],
    reverse=True
)[:10])

print("\n📊 ESTADÍSTICAS CONSOLIDADAS DE GRYPE")
print(f"{'='*60}")
print(
    f"\n📁 Repositorios analizados: {stats_consolidadas['total_repositories']}")
print(
    f"🔴 Total de vulnerabilidades: {stats_consolidadas['total_vulnerabilities']}")

print(f"\n📋 Vulnerabilidades por repositorio:")
for repo, count in stats_consolidadas['vulnerabilities_by_repo'].items():
    print(f"  • {repo}: {count}")

print(f"\n⚠️  Vulnerabilidades por severidad:")
for severity, count in sorted(stats_consolidadas['vulnerabilities_by_severity'].items()):
    emoji = "🔴" if severity == "critical" else "🟠" if severity == "high" else "🟡" if severity == "medium" else "⚪"
    print(f"  {emoji} {severity}: {count}")

print(f"\n📦 Top 10 paquetes con vulnerabilidades:")
for pkg, count in list(stats_consolidadas['top_packages'].items())[:10]:
    print(f"  • {pkg}: {count}")
# Out:
# 📊 ESTADÍSTICAS CONSOLIDADAS DE GRYPE
# ============================================================
#
# 📁 Repositorios analizados: 9
# 🔴 Total de vulnerabilidades: 42
#
# 📋 Vulnerabilidades por repositorio:
#   • annotated-doc: 4
#   • asyncer: 5
#   • fastapi-cli: 1
#   • fastapi: 13
#   • fastapi-new: 2
#   • fastapi-vscode: 0
#   • full-stack-fastapi-template: 8
#   • sqlmodel: 8
#   • typer: 1
#
# ⚠️  Vulnerabilidades por severidad:
#   🔴 critical: 0
#   🟠 high: 0
#   ⚪ low: 42
#   🟡 medium: 0
#
# 📦 Top 10 paquetes con vulnerabilidades:
#   • unknown: 42

# %% [markdown]
# ## Próximos Pasos
#
# Los resultados del análisis Grype se han guardado en `data/results/` con los patrones:
# - `{repo-name}-grype-raw.json`: Salida original de Grype (útil para debug)
# - `{repo-name}-grype.json`: Formato normalizado (para análisis y visualización)
#
# ### Cómo usar estos resultados:
#
# 1. **Revisar vulnerabilidades críticas**: Filtrar por `vuln_severity: "critical"` para identificar problemas urgentes
# 2. **Seguimiento**: Integrar con sistemas de seguimiento (issues, PRs) para gestionar remediación
# 3. **Análisis de tendencias**: Comparar resultados entre repositorios y períodos de tiempo
# 4. **Actualizar dependencias**: Usar `fix_version` para actualizar librerías vulnerables
# 5. **Automatizar**: Integrar estos análisis en CI/CD para detectar problemas continuamente
#
# #### Para agregar nuevos repositorios:
#
# 1. **Edita `data/repos.json`** y agrega nuevos repositorios
# 2. **Ejecuta en la terminal**:
#
# ```bash
# uv run scripts/add_submodules.py && git submodule update --init --recursive
# ```
#
# 3. **Ejecuta el análisis** nuevamente desde el notebook o la terminal:
#
# ```bash
# uv run scripts/generate_grype.py
# ```
